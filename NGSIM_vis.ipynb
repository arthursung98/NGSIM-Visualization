# %%
# Import helper functions for animation class.
import NGSIM_utils as anim

# %%
# For synthetic data
# Initialize Animation Class
us101_anim = anim.Animation('i80.csv')

# %%
# Transform CSV File into individual Frame snapshots
us101_anim.csv_to_frames()
# Out:
# C:\I24 Motion Project\Anomaly Detection\src_vis\NGSIM_utils.py:30: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=(15,8))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
# ...

# %%
# Fetch image files from the folder, and create an animation.
us101_anim.animate()

# %%
import os
import pandas as pd

csv_dir = os.path.join(os.path.abspath(os.path.join(os.getcwd(), os.pardir)), "csv")
data_path = os.path.join(csv_dir, 'i80.csv')

df = pd.read_csv(data_path)
df = df.loc[(df['Location'] == 'i-80')]
df = df[['Vehicle_ID','Frame_ID','Local_X','Local_Y','v_length','v_Width','v_Class',\
         'Lane_ID','Preceding','Following','Space_Headway']]
df.columns = ['ID','Frame #','lateral','longitude','length','width','class',\
              'Lane','Preceding','Following','Space_Headway']

# %%
testdf = df.loc[(df['ID'] == 124)]
testdf = testdf.loc[testdf['Frame #'] < 770]
testdf = testdf.loc[testdf['Frame #'] > 730]
testdf.sort_values('Frame #')
# Out:
#           ID  Frame #  lateral  longitude  length  width  class  Lane  \
# 2983590  124      743   90.050    334.827    14.8    8.4      2     7
# 3906715  124      744   90.057    339.678    14.8    8.4      2     7
# 1821763  124      745   89.568    344.679    14.8    8.4      2     7
# 2178118  124      746   89.080    349.180    14.8    8.4      2     7
# 3509090  124      747   89.094    354.681    14.8    8.4      2     7
# 1890528  124      748   88.757    359.683    14.8    8.4      2     7
# 2345153  124      749   88.619    364.862    14.8    8.4      2     7
# 1906487  124      750   88.451    369.986    14.8    8.4      2     7
# 4177423  124      751   88.325    375.189    14.8    8.4      2     7
# 2992723  124      752   88.157    380.485    14.8    8.4      2     7
# 2409119  124      753   88.010    385.815    14.8    8.4      2     7
# 1922276  124      754   87.778    391.029    14.8    8.4      2     7
# ...
